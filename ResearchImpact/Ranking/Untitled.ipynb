# %%
import pandas as pd

# %%
df = pd.read_json("ranking_institucional_2020-04-12.json")

# %%
df
# Out:
#                                                                 0    \
# autor                                               Abad, Andres G.
# NOMBREUNIDAD      Facultad de Ingeniería en Mecánica y Ciencias ...
# ranking_profesor                                          0.0259562
#
#                                                                 1    \
# autor                                             Abad, Cristina L.
# NOMBREUNIDAD      Facultad de Ingeniería en Electricidad y Compu...
# ranking_profesor                                         0.00797488
#
#                                                                 2    \
# autor                                                Acosta, Sandra
# NOMBREUNIDAD      Facultad de Ingeniería en Mecánica y Ciencias ...
# ranking_profesor                                          0.0175119
#
#                                                                 3    \
# autor                                                     Agila, W.
# ...

# %%
df = df.T

# %%
df
# Out:
#                        autor  \
# 0            Abad, Andres G.
# 1          Abad, Cristina L.
# 2             Acosta, Sandra
# 3                  Agila, W.
# 4          Alava, Eduardo I.
# ..                       ...
# 171     Vintimilla, Boris X.
# 172            Vitvar, Tomáš
# 173            Wong, Sara A.
# 174  Yonfá-Medranda, Marcela
# 175         Zanzzi, Fabricio
#
#                                           NOMBREUNIDAD ranking_profesor
# 0    Facultad de Ingeniería en Mecánica y Ciencias ...        0.0259562
# 1    Facultad de Ingeniería en Electricidad y Compu...       0.00797488
# 2    Facultad de Ingeniería en Mecánica y Ciencias ...        0.0175119
# 3    Facultad de Ingeniería en Electricidad y Compu...       0.00110905
# 4                      Facultad de Ciencias de la Vida      7.34459e-05
# ..                                                 ...              ...
# 171  Facultad de Ingeniería en Electricidad y Compu...        0.0126498
# ...

# %%
df.ranking_profesor.max()
# Out:
# 0.0860798186

# %%
df[df.ranking_profesor == 0.0860798186]
# Out:
#                     autor                     NOMBREUNIDAD ranking_profesor
# 166  Van Den Hende, Sofie  Facultad de Ciencias de la Vida        0.0860798
